# %% [markdown]
# # API 1 - MOD-4 Vasquez Jorge Luis

# %% [markdown]
# ### Actividad 1 - Procesamiento Natural del Lenguaje (NLP)
# #### Concesionaria AutoFlex - Análisis de sentimientos
#
# Este notebook contiene la solución completa a los 5 puntos solicitados.

# %%
# Celda 1: Importación de librerías necesarias
import pandas as pd
import re
import matplotlib.pyplot as plt

# Nota: No se instalan librerías, solo se importan las ya existentes.
